# %% [markdown]
# https://github.com/RuggeroFreddi/gan-monet-style-transfer.git

# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
        print(dirname)
# Out:
# /kaggle/input
# /kaggle/input/gan-getting-started
# /kaggle/input/gan-getting-started/monet_jpg
# /kaggle/input/gan-getting-started/photo_tfrec
# /kaggle/input/gan-getting-started/photo_jpg
# /kaggle/input/gan-getting-started/monet_tfrec

# %% [markdown]
# # I’m Something of a Painter Myself
# ### Mini-Project: Generative Adversarial Networks for Artistic Style Generation
#
# This mini-project is focused on building and training deep generative learning models. The goal is to gain hands-on experience with Generative Adversarial Networks (GANs) by applying them to an image generation task inspired by artistic style transfer. The project uses a Kaggle “Getting Started” competition as a practical framework for model development, evaluation, and comparison.
#
# ---
#
# ## Problem Description
#
# The objective of this project is to build a generative model capable of producing images that resemble the artistic style of Claude Monet. Specifically, the task is to train a Generative Adversarial Network (GAN) to generate novel images that capture characteristic features of Monet’s paintings, such as color palettes, textures, and brush-stroke patterns.
#
# GANs consist of two competing neural networks: a generator, which attempts to create realistic images, and a discriminator, which learns to distinguish between real images and generated ones. Through this adversarial training process, the generator progressively improves its ability to produce high-quality, realistic images.
#
# This problem is relevant because it demonstrates how modern deep learning models can learn complex visual distributions and creative styles, highlighting the intersection between computer vision, unsupervised learning, and computational creativity.

# %% [markdown]
# ## Data Description
#
# The dataset used in this project consists of image data provided by the Kaggle *“I’m Something of a Painter Myself”* competition. The data is designed for training generative models to learn and reproduce an artistic style.
#
# - **Data type**:
#   - Monet paintings (target domain), representing the artistic style to be learned.
#   - Photographs (source domain), which can be used as input images when applying style transfer approaches such as CycleGAN.
#
# - **Image format**:
#   - Images are RGB with shape **256 × 256 × 3** after preprocessing/resizing (as required for model training and submission).
#
# - **Data size (as observed in this notebook environment)**:
#   - **Monet JPG** folder: **300** images
#   - **Photo JPG** folder: **7,038** images
#
# - **Data structure**:
#   - Images are available both as **JPG files** (`monet_jpg/`, `photo_jpg/`) and as **TFRecords** (`monet_tfrec/`, `photo_tfrec/`) for more efficient TensorFlow input pipelines.
#   - No labels are provided, since this is an **unsupervised** image generation / style learning task.
#
# Overall, the dataset is suitable for training GAN-based models to learn the visual distribution of Monet-style paintings and generate new images consistent with that style.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# This section performs a basic exploratory analysis of the image datasets used in the project in order to better understand their structure and properties before model training.
#
# First, a small set of sample images is visualized from both domains (Monet paintings and real photographs) to qualitatively inspect visual characteristics such as color distributions, textures, and overall style differences between the two datasets.
#
# Next, the image dimensions are verified across the entire dataset to ensure consistency. All images are checked against the expected input size of **256 × 256 pixels**, which is required for training the GAN models and for compatibility with the Kaggle competition submission format.
#
# Additionally, pixel value ranges and data types are inspected after decoding and resizing. Different normalization strategies are examined, including scaling pixel values to the **[0, 1]** range and to the **[-1, 1]** range, which is commonly used in GAN training. This step helps confirm that the preprocessing pipeline produces correctly formatted inputs for the generator and discriminator networks.
#
# Overall, this EDA confirms that the datasets are well-structured, consistently sized, and suitable for training GAN-based generative models.

# %%
# =========================
# Data Loading + EDA (CPU-only)
# =========================

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"   # 0=all, 1=filter INFO, 2=filter WARNING, 3=filter ERROR

import glob, random
from pathlib import Path

import matplotlib.pyplot as plt
from PIL import Image

import tensorflow as tf

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

# -------------------------
# Paths (given)
# -------------------------
ROOT = Path("/kaggle/input/gan-getting-started")
MONET_JPG_DIR   = ROOT / "monet_jpg"
PHOTO_JPG_DIR   = ROOT / "photo_jpg"
MONET_TFREC_DIR = ROOT / "monet_tfrec"
PHOTO_TFREC_DIR = ROOT / "photo_tfrec"

print("Root:", ROOT)
print("Monet JPG:", MONET_JPG_DIR)
print("Photo JPG:", PHOTO_JPG_DIR)
print("Monet TFRecords:", MONET_TFREC_DIR)
print("Photo TFRecords:", PHOTO_TFREC_DIR)

# -------------------------
# Helpers
# -------------------------
def list_files(dir_path: Path, exts=(".jpg", ".jpeg", ".png")):
    files = []
    for ext in exts:
        files.extend(sorted(glob.glob(str(dir_path / f"*{ext}"))))
    return files

def show_grid_from_paths(paths, rows=2, cols=3, title=None):
    """Show a small fixed grid (default 3x2) to avoid excessive visualization."""
    paths = list(paths)
    n = rows * cols
    if len(paths) == 0:
        print(f"[WARN] No images to display for: {title}")
        return

    sample = random.sample(paths, k=min(n, len(paths)))
    plt.figure(figsize=(cols * 4, rows * 4))
    if title:
        plt.suptitle(title, fontsize=14)

    for i, p in enumerate(sample, start=1):
        img = Image.open(p).convert("RGB")
        w, h = img.size
        plt.subplot(rows, cols, i)
        plt.imshow(img)
        plt.axis("off")
        plt.title(f"{w}x{h}", fontsize=10)

    plt.tight_layout()
    plt.show()

def check_all_sizes(paths, expected_w=256, expected_h=256, label=""):
    """
    Verify that ALL images match expected size.
    Reports width check and height check separately + up to 10 mismatches.
    """
    paths = list(paths)
    if len(paths) == 0:
        print(f"[WARN] No images found for {label}")
        return

    width_ok = True
    height_ok = True
    mismatches = []

    for p in paths:
        with Image.open(p) as img:
            w, h = img.size
        if w != expected_w:
            width_ok = False
        if h != expected_h:
            height_ok = False
        if (w != expected_w) or (h != expected_h):
            mismatches.append((p, w, h))

    print(f"\n[{label}] Total images: {len(paths)}")
    print(f"[{label}] All widths == {expected_w}: {width_ok}")
    print(f"[{label}] All heights == {expected_h}: {height_ok}")

    if mismatches:
        print(f"[{label}] Mismatches found: {len(mismatches)} (showing up to 10)")
        for p, w, h in mismatches[:10]:
            print(f"  - {p} -> {w}x{h}")
    else:
        print(f"[{label}] No size mismatches found.")

# -------------------------
# Load JPG file lists
# -------------------------
monet_jpg_paths = list_files(MONET_JPG_DIR, exts=(".jpg", ".jpeg"))
photo_jpg_paths = list_files(PHOTO_JPG_DIR, exts=(".jpg", ".jpeg"))

print(f"Monet JPG count: {len(monet_jpg_paths)}")
print(f"Photo JPG count: {len(photo_jpg_paths)}")

# -------------------------
# TFRecords discovery (informational)
# -------------------------
monet_tfrec_files = sorted(glob.glob(str(MONET_TFREC_DIR / "*.tfrec"))) + sorted(glob.glob(str(MONET_TFREC_DIR / "*.tfrecord*")))
photo_tfrec_files = sorted(glob.glob(str(PHOTO_TFREC_DIR / "*.tfrec"))) + sorted(glob.glob(str(PHOTO_TFREC_DIR / "*.tfrecord*")))

print(f"Monet TFRecord files: {len(monet_tfrec_files)}")
print(f"Photo TFRecord files: {len(photo_tfrec_files)}")

# -------------------------
# EDA: show few sample images (3x2 each)
# -------------------------
show_grid_from_paths(monet_jpg_paths, rows=2, cols=3, title="Monet JPG Samples (3x2)")
show_grid_from_paths(photo_jpg_paths, rows=2, cols=3, title="Photo JPG Samples (3x2)")

# -------------------------
# EDA: size checks only 
# -------------------------
check_all_sizes(monet_jpg_paths, expected_w=256, expected_h=256, label="Monet JPG")
check_all_sizes(photo_jpg_paths, expected_w=256, expected_h=256, label="Photo JPG")

# -------------------------
# Preprocessing functions 
# -------------------------
IMG_SIZE = 256

def decode_and_resize_jpg(path, img_size=IMG_SIZE):
    img_bytes = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img_bytes, channels=3)
    img = tf.image.resize(img, [img_size, img_size], method="bilinear")
    img = tf.cast(img, tf.float32)
    return img

def normalize_01(img):
    return img / 255.0

def normalize_m11(img):
    return (img / 127.5) - 1.0

# -------------------------
# Quick check: dtype/range after preprocessing 
# -------------------------
def inspect_preprocessing(paths, n=4, label=""):
    if len(paths) == 0:
        return
    sample = random.sample(list(paths), k=min(n, len(paths)))
    imgs = [decode_and_resize_jpg(p) for p in sample]
    batch = tf.stack(imgs, axis=0)  # [B, H, W, C]

    batch_01 = normalize_01(batch)
    batch_m11 = normalize_m11(batch)

    print(f"\n[{label}] Raw batch:", batch.shape, batch.dtype,
          "min/max:", float(tf.reduce_min(batch)), float(tf.reduce_max(batch)))
    print(f"[{label}] 0..1 batch:", batch_01.shape, batch_01.dtype,
          "min/max:", float(tf.reduce_min(batch_01)), float(tf.reduce_max(batch_01)))
    print(f"[{label}] -1..1 batch:", batch_m11.shape, batch_m11.dtype,
          "min/max:", float(tf.reduce_min(batch_m11)), float(tf.reduce_max(batch_m11)))

inspect_preprocessing(monet_jpg_paths, n=4, label="Monet")
inspect_preprocessing(photo_jpg_paths, n=4, label="Photo")

# -------------------------
# EDA: pixel intensity histograms (Monet vs Photo)
# -------------------------
def plot_pixel_histograms(paths, n=24, title_prefix=""):
    """
    Plot grayscale intensity histogram + per-channel RGB histograms
    using a small random sample of images to keep it lightweight.
    """
    if len(paths) == 0:
        print(f"[WARN] No images available for histogram: {title_prefix}")
        return

    sample = random.sample(list(paths), k=min(n, len(paths)))

    # Accumulate pixel values for histograms
    gray_vals = []
    r_vals, g_vals, b_vals = [], [], []

    for p in sample:
        img = decode_and_resize_jpg(p, IMG_SIZE)          # float32 0..255
        img01 = normalize_01(img)                         # 0..1
        img01 = tf.clip_by_value(img01, 0.0, 1.0)

        # Grayscale intensity (simple average across channels)
        gray = tf.reduce_mean(img01, axis=-1)             # [H,W]
        gray_vals.append(tf.reshape(gray, [-1]))

        # Per-channel
        r_vals.append(tf.reshape(img01[..., 0], [-1]))
        g_vals.append(tf.reshape(img01[..., 1], [-1]))
        b_vals.append(tf.reshape(img01[..., 2], [-1]))

    gray_vals = tf.concat(gray_vals, axis=0).numpy()
    r_vals = tf.concat(r_vals, axis=0).numpy()
    g_vals = tf.concat(g_vals, axis=0).numpy()
    b_vals = tf.concat(b_vals, axis=0).numpy()

    # Grayscale histogram
    plt.figure(figsize=(8, 4))
    plt.hist(gray_vals, bins=50)
    plt.title(f"{title_prefix} - Grayscale Intensity Histogram (sample n={len(sample)})")
    plt.xlabel("Intensity (0..1)")
    plt.ylabel("Pixel count")
    plt.tight_layout()
    plt.show()

    # RGB histograms (overlayed)
    plt.figure(figsize=(8, 4))
    plt.hist(r_vals, bins=50, alpha=0.5, label="R")
    plt.hist(g_vals, bins=50, alpha=0.5, label="G")
    plt.hist(b_vals, bins=50, alpha=0.5, label="B")
    plt.title(f"{title_prefix} - RGB Channel Histograms (sample n={len(sample)})")
    plt.xlabel("Intensity (0..1)")
    plt.ylabel("Pixel count")
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_pixel_histograms(monet_jpg_paths, n=24, title_prefix="Monet")
plot_pixel_histograms(photo_jpg_paths, n=24, title_prefix="Photo")

# -------------------------
# Build tf.data pipelines (JPG) for training (CPU)
# -------------------------
AUTOTUNE = tf.data.AUTOTUNE

def make_jpg_dataset(paths, batch_size=16, shuffle=True, repeat=True, norm="m11"):
    ds = tf.data.Dataset.from_tensor_slices(paths)
    if shuffle:
        ds = ds.shuffle(buffer_size=min(len(paths), 2048), reshuffle_each_iteration=True)
    ds = ds.map(lambda p: decode_and_resize_jpg(p, IMG_SIZE), num_parallel_calls=AUTOTUNE)
    if norm == "m11":
        ds = ds.map(normalize_m11, num_parallel_calls=AUTOTUNE)
    elif norm == "01":
        ds = ds.map(normalize_01, num_parallel_calls=AUTOTUNE)
    if repeat:
        ds = ds.repeat()
    ds = ds.batch(batch_size, drop_remainder=True).prefetch(AUTOTUNE)
    return ds

# Example datasets (for later training)
monet_ds = make_jpg_dataset(monet_jpg_paths, batch_size=16, shuffle=True, repeat=True, norm="m11")
photo_ds = make_jpg_dataset(photo_jpg_paths, batch_size=16, shuffle=True, repeat=True, norm="m11")

# Peek one batch
m_batch = next(iter(monet_ds.take(1)))
p_batch = next(iter(photo_ds.take(1)))
print("\nMonet batch:", m_batch.shape, m_batch.dtype, "min/max:", float(tf.reduce_min(m_batch)), float(tf.reduce_max(m_batch)))
print("Photo batch:", p_batch.shape, p_batch.dtype, "min/max:", float(tf.reduce_min(p_batch)), float(tf.reduce_max(p_batch)))
# Out:
# Root: /kaggle/input/gan-getting-started
# Monet JPG: /kaggle/input/gan-getting-started/monet_jpg
# Photo JPG: /kaggle/input/gan-getting-started/photo_jpg
# Monet TFRecords: /kaggle/input/gan-getting-started/monet_tfrec
# Photo TFRecords: /kaggle/input/gan-getting-started/photo_tfrec
# Monet JPG count: 300
# Photo JPG count: 7038
# Monet TFRecord files: 5
# Photo TFRecord files: 20
# [Monet JPG] Total images: 300
# [Monet JPG] All widths == 256: True
# [Monet JPG] All heights == 256: True
# [Monet JPG] No size mismatches found.
#
# [Photo JPG] Total images: 7038
# [Photo JPG] All widths == 256: True
# [Photo JPG] All heights == 256: True
# [Photo JPG] No size mismatches found.
#
# [Monet] Raw batch: (4, 256, 256, 3) <dtype: 'float32'> min/max: 0.0 255.0
# [Monet] 0..1 batch: (4, 256, 256, 3) <dtype: 'float32'> min/max: 0.0 1.0
# [Monet] -1..1 batch: (4, 256, 256, 3) <dtype: 'float32'> min/max: -1.0 1.0
#
# [Photo] Raw batch: (4, 256, 256, 3) <dtype: 'float32'> min/max: 0.0 255.0
# [Photo] 0..1 batch: (4, 256, 256, 3) <dtype: 'float32'> min/max: 0.0 1.0
# [Photo] -1..1 batch: (4, 256, 256, 3) <dtype: 'float32'> min/max: -1.0 1.0
# Monet batch: (16, 256, 256, 3) <dtype: 'float32'> min/max: -1.0 1.0
# Photo batch: (16, 256, 256, 3) <dtype: 'float32'> min/max: -1.0 1.0

# %% [markdown]
# ## Comment on EDA Results
#
# The exploratory data analysis highlights several important characteristics of the datasets used in this project.
#
# From the visual inspection of sample images, clear stylistic differences are observed between the Monet paintings and real photographs. Monet images tend to exhibit softer textures, less sharp edges, and more homogeneous color regions, while photographs show higher contrast, sharper boundaries, and more detailed structures.
#
# The image size analysis confirms that all images are consistently resized to **256 × 256 pixels**, with no detected mismatches. This ensures compatibility with the GAN architecture and avoids issues related to variable input dimensions during training.
#
# The pixel intensity histograms provide additional quantitative insight. While both datasets span the full intensity range, the Monet images show smoother and more evenly distributed grayscale and RGB channel histograms, whereas photographs display more pronounced peaks and higher contrast across channels. These differences are consistent with the artistic style of paintings versus natural images.
#
# Overall, the EDA confirms that the datasets are well-structured, properly preprocessed, and exhibit meaningful distributional differences that justify the use of GAN-based models to learn and reproduce the Monet painting style.

# %% [markdown]
# ## Model Choice and Motivation
#
# For this project, a **Generative Adversarial Network (GAN)** architecture is required to generate images in the style of Claude Monet. Among the available GAN-based approaches, **CycleGAN** is a natural and well-established choice for this task.
#
# CycleGAN is designed for **unpaired image-to-image translation**, meaning it can learn a mapping between two visual domains without requiring one-to-one correspondence between images. In this case, the two domains are:
# - photographs (source domain)
# - Monet-style paintings (target domain)
#
# This property is particularly important because the dataset does not provide paired photo–painting examples. CycleGAN addresses this by using two generators and two discriminators, along with a **cycle-consistency constraint**, which encourages the translated images to preserve the underlying content of the original images while adopting the target style.
#
# The use of CycleGAN allows the model to:
# - learn stylistic features such as color distributions and texture patterns from Monet paintings,
# - preserve structural content from photographs,
# - operate in a fully unsupervised setting, consistent with the dataset characteristics.
#
# Given these properties, CycleGAN provides a robust and conceptually appropriate baseline for learning Monet-style image generation in this mini-project.

# %% [markdown]
# ## Hyperparameter Selection and Tuning
#
# The CycleGAN model was trained using a set of hyperparameters commonly adopted in the literature and in baseline implementations for image-to-image translation tasks.
#
# In particular, the learning rate, batch size, and optimizer were selected based on standard practices for GAN training, balancing training stability and convergence speed. The cycle-consistency loss weight was chosen to ensure that the generated images preserve the structural content of the input photographs while allowing sufficient flexibility to learn the target artistic style.
#
# During experimentation, these hyperparameters were adjusted empirically by observing training behavior, including generator and discriminator loss trends and the visual quality of generated images. This iterative process helped avoid common GAN training issues such as mode collapse and unstable adversarial dynamics.
#
# Overall, the selected hyperparameters provided a reasonable trade-off between training stability and output image quality for this mini-project.

# %% [markdown]
# ## Comparison with Alternative Architectures
#
# Several alternative generative modeling approaches were considered for this task. For example, paired image-to-image translation models such as Pix2Pix require aligned photo–painting pairs, which are not available in this dataset. As a result, these methods are not suitable for the current problem setting.
#
# Other GAN architectures, such as DCGAN or StyleGAN, are primarily designed for unconditional image generation and do not explicitly enforce content preservation between source and target domains. While powerful, these models are less appropriate when the goal is to translate images from one domain to another while maintaining structural consistency.
#
# CycleGAN was therefore selected because it explicitly addresses the unpaired nature of the dataset and introduces cycle-consistency constraints that encourage meaningful mappings between photographs and Monet-style paintings.
#
# Given these considerations, CycleGAN represents a well-justified and appropriate architectural choice for this project compared to alternative generative approaches.

# %%
# =========================
# CycleGAN - Model Architecture (tf.keras) 
# Generators: ResNet-style with Conv(stride=2) downsampling + Residual blocks + UpSampling
# Discriminators: PatchGAN producing logits (no sigmoid) for BCEWithLogits
# =========================

# -------------------------
# Building Blocks (merged conv block)
# -------------------------
def conv_norm_act(
    x,
    filters,
    kernel_size=3,
    strides=1,
    padding="same",
    use_norm=True,
    act="relu",          # "relu" or "lrelu"
    lrelu_alpha=0.2,
    name=None,
):
    x = tf.keras.layers.Conv2D(
        filters,
        kernel_size,
        strides=strides,
        padding=padding,
        use_bias=not use_norm,
        kernel_initializer="he_normal",
        name=None if name is None else f"{name}_conv",
    )(x)

    if use_norm:
        x = tf.keras.layers.BatchNormalization(
            name=None if name is None else f"{name}_bn"
        )(x)

    if act == "relu":
        x = tf.keras.layers.ReLU(name=None if name is None else f"{name}_relu")(x)
    elif act == "lrelu":
        x = tf.keras.layers.LeakyReLU(lrelu_alpha, name=None if name is None else f"{name}_lrelu")(x)
    else:
        raise ValueError("act must be 'relu' or 'lrelu'")

    return x

def residual_block(x, filters, name=None):
    """
    Minimal ResNet block for generator:
    x -> Conv -> BN -> ReLU -> Conv -> BN -> Add(skip)
    """
    skip = x

    y = tf.keras.layers.Conv2D(
        filters, 3, strides=1, padding="same", use_bias=False,
        kernel_initializer="he_normal",
        name=None if name is None else f"{name}_c1",
    )(x)
    y = tf.keras.layers.BatchNormalization(name=None if name is None else f"{name}_bn1")(y)
    y = tf.keras.layers.ReLU(name=None if name is None else f"{name}_relu")(y)

    y = tf.keras.layers.Conv2D(
        filters, 3, strides=1, padding="same", use_bias=False,
        kernel_initializer="he_normal",
        name=None if name is None else f"{name}_c2",
    )(y)
    y = tf.keras.layers.BatchNormalization(name=None if name is None else f"{name}_bn2")(y)

    out = tf.keras.layers.Add(name=None if name is None else f"{name}_add")([skip, y])
    return out

# -------------------------
# Generator (ResNet-style)
# -------------------------
def build_generator(name="generator", img_size=256, base_filters=64, n_res_blocks=6):
    """
    Input:  (img_size, img_size, 3) normalized to [-1, 1]
    Output: (img_size, img_size, 3) with tanh in [-1, 1]
    """
    inp = tf.keras.layers.Input(shape=(img_size, img_size, 3), name=f"{name}_input")

    # Initial conv
    x = conv_norm_act(inp, base_filters, kernel_size=7, strides=1, padding="same",
                      use_norm=True, act="relu", name=f"{name}_init")

    # Downsampling: 256 -> 128 -> 64
    x = conv_norm_act(x, base_filters * 2, kernel_size=3, strides=2, padding="same",
                      use_norm=True, act="relu", name=f"{name}_down1")
    x = conv_norm_act(x, base_filters * 4, kernel_size=3, strides=2, padding="same",
                      use_norm=True, act="relu", name=f"{name}_down2")

    # Residual blocks at 64x64
    for i in range(n_res_blocks):
        x = residual_block(x, base_filters * 4, name=f"{name}_res{i+1}")

    # Upsampling: 64 -> 128 -> 256 (nearest + conv)
    x = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation="nearest", name=f"{name}_up1")(x)
    x = conv_norm_act(x, base_filters * 2, kernel_size=3, strides=1, padding="same",
                      use_norm=True, act="relu", name=f"{name}_up1_conv")

    x = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation="nearest", name=f"{name}_up2")(x)
    x = conv_norm_act(x, base_filters, kernel_size=3, strides=1, padding="same",
                      use_norm=True, act="relu", name=f"{name}_up2_conv")

    # Output conv -> tanh
    out = tf.keras.layers.Conv2D(
        3, 7, strides=1, padding="same",
        kernel_initializer="glorot_uniform",
        name=f"{name}_out_conv",
    )(x)
    out = tf.keras.layers.Activation("tanh", name=f"{name}_tanh")(out)

    return tf.keras.Model(inp, out, name=name)

# -------------------------
# PatchGAN Discriminator (logits)
# -------------------------
def build_discriminator(name="discriminator", img_size=256, base_filters=64):
    """
    PatchGAN discriminator.
    Input:  (img_size, img_size, 3) in [-1, 1]
    Output: (H', W', 1) logits map (no sigmoid) for BCEWithLogits
    """
    inp = tf.keras.layers.Input(shape=(img_size, img_size, 3), name=f"{name}_input")

    # First layer usually without norm
    x = conv_norm_act(inp, base_filters, kernel_size=4, strides=2, padding="same",
                      use_norm=False, act="lrelu", name=f"{name}_c1")
    x = conv_norm_act(x, base_filters * 2, kernel_size=4, strides=2, padding="same",
                      use_norm=True, act="lrelu", name=f"{name}_c2")

    x = conv_norm_act(x, base_filters * 4, kernel_size=4, strides=2, padding="same",
                      use_norm=True, act="lrelu", name=f"{name}_c3")
    x = conv_norm_act(x, base_filters * 8, kernel_size=4, strides=1, padding="same",
                      use_norm=True, act="lrelu", name=f"{name}_c4")

    # Final conv to 1 channel logits map (no activation)
    out = tf.keras.layers.Conv2D(
        1, 4, strides=1, padding="same",
        kernel_initializer="he_normal",
        name=f"{name}_out_logits",
    )(x)

    return tf.keras.Model(inp, out, name=name)

# -------------------------
# Instantiate CycleGAN components
# -------------------------
IMG_SIZE = 256
BASE_FILTERS_G = 16
BASE_FILTERS_D = 16
N_RES_BLOCKS = 4  # from 3 to 6

G_photo2monet = build_generator("G_photo2monet", img_size=IMG_SIZE, base_filters=BASE_FILTERS_G, n_res_blocks=N_RES_BLOCKS)
F_monet2photo = build_generator("F_monet2photo", img_size=IMG_SIZE, base_filters=BASE_FILTERS_G, n_res_blocks=N_RES_BLOCKS)

D_monet = build_discriminator("D_monet", img_size=IMG_SIZE, base_filters=BASE_FILTERS_D)
D_photo = build_discriminator("D_photo", img_size=IMG_SIZE, base_filters=BASE_FILTERS_D)

# Print summaries (optional)
G_photo2monet.summary()
D_monet.summary()

# Quick shape check
x = tf.random.uniform([1, IMG_SIZE, IMG_SIZE, 3], minval=-1.0, maxval=1.0)
y = G_photo2monet(x)
d = D_monet(y)
print("Generator output:", y.shape, "range approx:", float(tf.reduce_min(y)), float(tf.reduce_max(y)))
print("Discriminator output (logits map):", d.shape)
# Out:
# Model: "G_photo2monet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ G_photo2monet_input │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_init… │ (None, 256, 256,  │      2,352 │ G_photo2monet_in… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_init… │ (None, 256, 256,  │         64 │ G_photo2monet_in… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_init… │ (None, 256, 256,  │          0 │ G_photo2monet_in… │
# │ (ReLU)              │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_down… │ (None, 128, 128,  │      4,608 │ G_photo2monet_in… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_down… │ (None, 128, 128,  │        128 │ G_photo2monet_do… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_down… │ (None, 128, 128,  │          0 │ G_photo2monet_do… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_down… │ (None, 64, 64,    │     18,432 │ G_photo2monet_do… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_down… │ (None, 64, 64,    │        256 │ G_photo2monet_do… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_down… │ (None, 64, 64,    │          0 │ G_photo2monet_do… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res1… │ (None, 64, 64,    │     36,864 │ G_photo2monet_do… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res1… │ (None, 64, 64,    │        256 │ G_photo2monet_re… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res1… │ (None, 64, 64,    │          0 │ G_photo2monet_re… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res1… │ (None, 64, 64,    │     36,864 │ G_photo2monet_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res1… │ (None, 64, 64,    │        256 │ G_photo2monet_re… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res1… │ (None, 64, 64,    │          0 │ G_photo2monet_do… │
# │ (Add)               │ 64)               │            │ G_photo2monet_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res2… │ (None, 64, 64,    │     36,864 │ G_photo2monet_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res2… │ (None, 64, 64,    │        256 │ G_photo2monet_re… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res2… │ (None, 64, 64,    │          0 │ G_photo2monet_re… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res2… │ (None, 64, 64,    │     36,864 │ G_photo2monet_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res2… │ (None, 64, 64,    │        256 │ G_photo2monet_re… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res2… │ (None, 64, 64,    │          0 │ G_photo2monet_re… │
# │ (Add)               │ 64)               │            │ G_photo2monet_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res3… │ (None, 64, 64,    │     36,864 │ G_photo2monet_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res3… │ (None, 64, 64,    │        256 │ G_photo2monet_re… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res3… │ (None, 64, 64,    │          0 │ G_photo2monet_re… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res3… │ (None, 64, 64,    │     36,864 │ G_photo2monet_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res3… │ (None, 64, 64,    │        256 │ G_photo2monet_re… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res3… │ (None, 64, 64,    │          0 │ G_photo2monet_re… │
# │ (Add)               │ 64)               │            │ G_photo2monet_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res4… │ (None, 64, 64,    │     36,864 │ G_photo2monet_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res4… │ (None, 64, 64,    │        256 │ G_photo2monet_re… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res4… │ (None, 64, 64,    │          0 │ G_photo2monet_re… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res4… │ (None, 64, 64,    │     36,864 │ G_photo2monet_re… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res4… │ (None, 64, 64,    │        256 │ G_photo2monet_re… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_res4… │ (None, 64, 64,    │          0 │ G_photo2monet_re… │
# │ (Add)               │ 64)               │            │ G_photo2monet_re… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_up1   │ (None, 128, 128,  │          0 │ G_photo2monet_re… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_up1_… │ (None, 128, 128,  │     18,432 │ G_photo2monet_up… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_up1_… │ (None, 128, 128,  │        128 │ G_photo2monet_up… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_up1_… │ (None, 128, 128,  │          0 │ G_photo2monet_up… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_up2   │ (None, 256, 256,  │          0 │ G_photo2monet_up… │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_up2_… │ (None, 256, 256,  │      4,608 │ G_photo2monet_up… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_up2_… │ (None, 256, 256,  │         64 │ G_photo2monet_up… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_up2_… │ (None, 256, 256,  │          0 │ G_photo2monet_up… │
# │ (ReLU)              │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_out_… │ (None, 256, 256,  │      2,355 │ G_photo2monet_up… │
# │ (Conv2D)            │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G_photo2monet_tanh  │ (None, 256, 256,  │          0 │ G_photo2monet_ou… │
# │ (Activation)        │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 348,387 (1.33 MB)
#  Trainable params: 347,043 (1.32 MB)
#  Non-trainable params: 1,344 (5.25 KB)
# Model: "D_monet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ D_monet_input (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c1_conv (Conv2D)        │ (None, 128, 128, 16)   │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c1_lrelu (LeakyReLU)    │ (None, 128, 128, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c2_conv (Conv2D)        │ (None, 64, 64, 32)     │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c2_bn                   │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c2_lrelu (LeakyReLU)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c3_conv (Conv2D)        │ (None, 32, 32, 64)     │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c3_bn                   │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c3_lrelu (LeakyReLU)    │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c4_conv (Conv2D)        │ (None, 32, 32, 128)    │       131,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c4_bn                   │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_c4_lrelu (LeakyReLU)    │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ D_monet_out_logits (Conv2D)     │ (None, 32, 32, 1)      │         2,049 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 175,761 (686.57 KB)
#  Trainable params: 175,313 (684.82 KB)
#  Non-trainable params: 448 (1.75 KB)
# Generator output: (1, 256, 256, 3) range approx: -1.0 1.0
# Discriminator output (logits map): (1, 32, 32, 1)

# %% [markdown]
# ## Hyperparameter Experiments and Practical Trade-offs
#
# The final choice of hyperparameters was strongly influenced by practical constraints related to training time and computational cost. CycleGAN training is inherently slow, especially when using deeper generators and higher channel counts, and full hyperparameter optimization was not feasible within the scope of this mini-project.
#
# During experimentation, configurations with very conservative settings (e.g., very small batch sizes or a low number of filters) often produced numerically reasonable loss values and appeared stable from a purely quantitative perspective. However, visual inspection of the generated images revealed that these configurations typically resulted in poor stylistic quality, limited texture diversity, and overly smooth or unrealistic outputs.
#
# Conversely, increasing model capacity (e.g., more residual blocks or more filters) generally improved visual quality and stylistic richness, but at the cost of significantly slower training and higher memory usage. In some cases, larger configurations also led to less stable adversarial dynamics when training time was limited.
#
# The final hyperparameter configuration was therefore selected as a compromise between computational feasibility and visual output quality. While not fully optimized, this choice allowed the model to learn meaningful stylistic features of Monet paintings while maintaining reasonable training stability and runtime constraints.

# %% [markdown]
# ## Loss Functions and Training Strategy
#
# CycleGAN trains two generators and two discriminators, one pair per domain:
#
# - **Generators**
#   - \(G: X \rightarrow Y\) maps photos \(X\) to Monet-style images \(Y\)
#   - \(F: Y \rightarrow X\) maps Monet-style images \(Y\) back to photos \(X\)
#
# - **Discriminators**
#   - \(D_Y\) distinguishes real Monet images from generated Monet-style images \(G(X)\)
#   - \(D_X\) distinguishes real photos from generated photos \(F(Y)\)
#
# ### 1) Adversarial Loss (BCE with logits)
#
# We use a binary cross-entropy loss with logits (no sigmoid in the discriminator output). Each discriminator produces a PatchGAN logits map, and the loss is computed over all patches and averaged.
#
# For a discriminator \(D\):
# - Real images should be classified as 1:
#   \[
#   \mathcal{L}_{D}^{real} = BCE(\mathbf{1}, D(real))
#   \]
# - Fake images should be classified as 0:
#   \[
#   \mathcal{L}_{D}^{fake} = BCE(\mathbf{0}, D(fake))
#   \]
# - Total discriminator loss:
#   \[
#   \mathcal{L}_{D} = \frac{1}{2}\left(\mathcal{L}_{D}^{real} + \mathcal{L}_{D}^{fake}\right)
#   \]
#
# For a generator (adversarial term), fake images should be classified as real:
# \[
# \mathcal{L}_{GAN}(G, D_Y) = BCE(\mathbf{1}, D_Y(G(X)))
# \]
# \[
# \mathcal{L}_{GAN}(F, D_X) = BCE(\mathbf{1}, D_X(F(Y)))
# \]
#
# ### 2) Cycle-Consistency Loss
#
# Cycle-consistency encourages the translation to preserve the underlying content. After translating forward and back, we want to recover the original image:
#
# \[
# \mathcal{L}_{cyc}(G,F) =
# \mathbb{E}_{x \sim X}\left[\|F(G(x)) - x\|_1\right] +
# \mathbb{E}_{y \sim Y}\left[\|G(F(y)) - y\|_1\right]
# \]
#
# We use an \(L1\) reconstruction loss because it typically produces sharper reconstructions than \(L2\).
#
# ### 3) Overall Training Objective
#
# The full CycleGAN training objective is obtained by combining the adversarial losses for both generators with the cycle-consistency loss. This combination allows the model to simultaneously learn realistic target-domain textures (through adversarial training) and preserve the semantic structure of the input images (through cycle-consistency).
#
# This training strategy is particularly well-suited for artistic style translation tasks, where visual realism alone is insufficient and content preservation is essential. By balancing these objectives, the model can generate Monet-style images that remain structurally consistent with the original photographs.

# %%
# =========================
# CycleGAN - Training (CPU-only) + Load-or-Train + Persistent Save (Kaggle)
# Additions for "Risultati e analisi" rubric:
# - Persist epoch metrics into a DataFrame (table)
# - Plot training curves (separate figures)
# - Save metrics CSV to /kaggle/working for reproducibility
# RULES (kept):
# - If saved generators exist -> LOAD them and SKIP training, SKIP saving.
# - Else -> (optionally restore checkpoint) TRAIN, then SAVE generators.
# =========================

import time

# -------------------------
# Persistent paths (Kaggle)
# -------------------------
SAVE_DIR = Path("/kaggle/working/saved_cyclegan_models")
G_DIR = SAVE_DIR / "G_photo2monet"
F_DIR = SAVE_DIR / "F_monet2photo"
SAVE_DIR.mkdir(parents=True, exist_ok=True)

# persistent checkpoints (optional resume)
CKPT_DIR = "/kaggle/working/checkpoints_cyclegan"
os.makedirs(CKPT_DIR, exist_ok=True)

# metrics artifacts
METRICS_CSV = Path("/kaggle/working/cyclegan_training_metrics.csv")

# -------------------------
# Hyperparameters
# -------------------------
EPOCHS = 3
STEPS_PER_EPOCH = 25
BATCH_SIZE = 4
LR = 2e-4
BETA_1 = 0.5
LAMBDA_CYC = 10.0

# -------------------------
# Losses (BCE with logits + L1 cycle)
# -------------------------
bce_logits = tf.keras.losses.BinaryCrossentropy(from_logits=True)
mae = tf.keras.losses.MeanAbsoluteError()

def discriminator_loss(d_real, d_fake):
    real_loss = bce_logits(tf.ones_like(d_real), d_real)
    fake_loss = bce_logits(tf.zeros_like(d_fake), d_fake)
    return 0.5 * (real_loss + fake_loss)

def generator_gan_loss(d_fake):
    return bce_logits(tf.ones_like(d_fake), d_fake)

def cycle_loss(real, cycled):
    return mae(real, cycled)

# -------------------------
# Optimizers
# -------------------------
g_optimizer  = tf.keras.optimizers.Adam(learning_rate=LR, beta_1=BETA_1)
f_optimizer  = tf.keras.optimizers.Adam(learning_rate=LR, beta_1=BETA_1)
dx_optimizer = tf.keras.optimizers.Adam(learning_rate=LR, beta_1=BETA_1)
dy_optimizer = tf.keras.optimizers.Adam(learning_rate=LR, beta_1=BETA_1)

# -------------------------
# Metrics (epoch averages)
# -------------------------
m_d_photo = tf.keras.metrics.Mean(name="D_photo_loss")
m_d_monet = tf.keras.metrics.Mean(name="D_monet_loss")
m_g_adv   = tf.keras.metrics.Mean(name="G_adv_loss")
m_f_adv   = tf.keras.metrics.Mean(name="F_adv_loss")
m_cyc_x   = tf.keras.metrics.Mean(name="cycle_X_loss")
m_cyc_y   = tf.keras.metrics.Mean(name="cycle_Y_loss")
m_g_total = tf.keras.metrics.Mean(name="G_total_loss")

def reset_all_metrics():
    for m in [m_d_photo, m_d_monet, m_g_adv, m_f_adv, m_cyc_x, m_cyc_y, m_g_total]:
        m.reset_state()

# -------------------------
# Checkpointing (persistent)
# -------------------------
ckpt = tf.train.Checkpoint(
    G_photo2monet=G_photo2monet,
    F_monet2photo=F_monet2photo,
    D_photo=D_photo,
    D_monet=D_monet,
    g_optimizer=g_optimizer,
    f_optimizer=f_optimizer,
    dx_optimizer=dx_optimizer,
    dy_optimizer=dy_optimizer,
)
ckpt_manager = tf.train.CheckpointManager(ckpt, CKPT_DIR, max_to_keep=3)

# -------------------------
# SavedModel helpers (generators)
# -------------------------
def saved_generators_exist():
    # A SavedModel directory contains "saved_model.pb" (and variables/)
    return (G_DIR / "saved_model.pb").exists() and (F_DIR / "saved_model.pb").exists()

def load_saved_generators():
    print("✅ Found saved generators. Loading and skipping training...")
    G_loaded = tf.keras.models.load_model(G_DIR, compile=False)
    F_loaded = tf.keras.models.load_model(F_DIR, compile=False)
    return G_loaded, F_loaded

def save_generators(G, F):
    print("💾 Saving generators to:", SAVE_DIR)
    tf.keras.models.save_model(G, G_DIR, overwrite=True, include_optimizer=False)
    tf.keras.models.save_model(F, F_DIR, overwrite=True, include_optimizer=False)
    print("✅ Saved generators:", G_DIR, "and", F_DIR)

# -------------------------
# Training history (for tables/plots)
# -------------------------
history = []  # list of dicts, one per epoch

def _metric_float(m):
    # robust conversion to python float
    return float(m.result().numpy())

# -------------------------
# One training step
# -------------------------
@tf.function
def train_step(real_x, real_y):
    with tf.GradientTape(persistent=True) as tape:
        fake_y = G_photo2monet(real_x, training=True)    # X -> Y
        fake_x = F_monet2photo(real_y, training=True)    # Y -> X

        cycled_x = F_monet2photo(fake_y, training=True)  # X -> Y -> X
        cycled_y = G_photo2monet(fake_x, training=True)  # Y -> X -> Y

        d_real_x = D_photo(real_x, training=True)
        d_fake_x = D_photo(fake_x, training=True)

        d_real_y = D_monet(real_y, training=True)
        d_fake_y = D_monet(fake_y, training=True)

        dx_loss = discriminator_loss(d_real_x, d_fake_x)
        dy_loss = discriminator_loss(d_real_y, d_fake_y)

        g_adv = generator_gan_loss(d_fake_y)
        f_adv = generator_gan_loss(d_fake_x)

        cyc_x = cycle_loss(real_x, cycled_x)
        cyc_y = cycle_loss(real_y, cycled_y)
        g_total = g_adv + f_adv + (LAMBDA_CYC * (cyc_x + cyc_y))

    g_grads  = tape.gradient(g_total, G_photo2monet.trainable_variables)
    f_grads  = tape.gradient(g_total, F_monet2photo.trainable_variables)
    dx_grads = tape.gradient(dx_loss,  D_photo.trainable_variables)
    dy_grads = tape.gradient(dy_loss,  D_monet.trainable_variables)

    g_optimizer.apply_gradients(zip(g_grads,  G_photo2monet.trainable_variables))
    f_optimizer.apply_gradients(zip(f_grads,  F_monet2photo.trainable_variables))
    dx_optimizer.apply_gradients(zip(dx_grads, D_photo.trainable_variables))
    dy_optimizer.apply_gradients(zip(dy_grads, D_monet.trainable_variables))

    m_d_photo.update_state(dx_loss)
    m_d_monet.update_state(dy_loss)
    m_g_adv.update_state(g_adv)
    m_f_adv.update_state(f_adv)
    m_cyc_x.update_state(cyc_x)
    m_cyc_y.update_state(cyc_y)
    m_g_total.update_state(g_total)

# -------------------------
# Post-training reporting helpers
# -------------------------
def report_training(history_rows, save_csv_path=METRICS_CSV):
    """
    Creates:
    - A metrics table (DataFrame)
    - Saves the table to CSV
    - Plots separate training curves (no subplots)
    """
    if not history_rows:
        print("[WARN] No training history to report (history empty).")
        return None

    df = pd.DataFrame(history_rows)

    # Nice ordering
    cols = ["epoch", "time_sec", "Dx", "Dy", "G_adv", "F_adv", "cycX", "cycY", "G_total"]
    df = df[cols]

    # Display table
    try:
        display(df)
    except NameError:
        # if display isn't available, fallback
        print(df)

    # Save CSV (artifact)
    df.to_csv(save_csv_path, index=False)
    print(f"✅ Saved metrics CSV to: {save_csv_path}")

    # Plot curves (separate figures)
    plt.figure(figsize=(8, 4))
    plt.plot(df["epoch"], df["G_total"])
    plt.title("G_total per epoca")
    plt.xlabel("Epoch")
    plt.ylabel("G_total")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 4))
    plt.plot(df["epoch"], df["Dx"])
    plt.title("D_photo loss (Dx) per epoca")
    plt.xlabel("Epoch")
    plt.ylabel("Dx")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 4))
    plt.plot(df["epoch"], df["Dy"])
    plt.title("D_monet loss (Dy) per epoca")
    plt.xlabel("Epoch")
    plt.ylabel("Dy")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 4))
    plt.plot(df["epoch"], df["cycX"])
    plt.title("cycle_X loss (cycX) per epoca")
    plt.xlabel("Epoch")
    plt.ylabel("cycX")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 4))
    plt.plot(df["epoch"], df["cycY"])
    plt.title("cycle_Y loss (cycY) per epoca")
    plt.xlabel("Epoch")
    plt.ylabel("cycY")
    plt.tight_layout()
    plt.show()

    return df

# -------------------------
# Training loop
# -------------------------
def train(epochs=EPOCHS, steps_per_epoch=STEPS_PER_EPOCH):
    # Clear any previous run history in this notebook session
    history.clear()

    photo_iter = iter(photo_ds)
    monet_iter = iter(monet_ds)

    for epoch in range(1, epochs + 1):
        reset_all_metrics()
        t0 = time.time()

        for step in range(1, steps_per_epoch + 1):
            real_x = next(photo_iter)
            real_y = next(monet_iter)

            train_step(real_x, real_y)

            if step % 10 == 0 or step == 1:
                print(
                    f"Epoch {epoch}/{epochs} | Step {step}/{steps_per_epoch} | "
                    f"Dx={m_d_photo.result():.4f} Dy={m_d_monet.result():.4f} | "
                    f"G_adv={m_g_adv.result():.4f} F_adv={m_f_adv.result():.4f} | "
                    f"cycX={m_cyc_x.result():.4f} cycY={m_cyc_y.result():.4f} | "
                    f"G_total={m_g_total.result():.4f}"
                )

        ckpt_path = ckpt_manager.save(checkpoint_number=epoch)
        dt = time.time() - t0

        # Capture epoch metrics for table/plots
        history.append({
            "epoch": epoch,
            "time_sec": dt,
            "Dx": _metric_float(m_d_photo),
            "Dy": _metric_float(m_d_monet),
            "G_adv": _metric_float(m_g_adv),
            "F_adv": _metric_float(m_f_adv),
            "cycX": _metric_float(m_cyc_x),
            "cycY": _metric_float(m_cyc_y),
            "G_total": _metric_float(m_g_total),
        })

        print(
            f"\n✅ Epoch {epoch} done in {dt/60:.2f} min | saved: {ckpt_path}\n"
            f"Final epoch metrics: "
            f"Dx={m_d_photo.result():.4f}, Dy={m_d_monet.result():.4f}, "
            f"G_adv={m_g_adv.result():.4f}, F_adv={m_f_adv.result():.4f}, "
            f"cycX={m_cyc_x.result():.4f}, cycY={m_cyc_y.result():.4f}, "
            f"G_total={m_g_total.result():.4f}\n"
        )

    # After training: produce report artifacts (table + plots + CSV)
    df = report_training(history, save_csv_path=METRICS_CSV)
    return df

# =========================
# MAIN: load-or-train
# =========================
if saved_generators_exist():
    G_photo2monet, F_monet2photo = load_saved_generators()
else:
    # optional resume from checkpoint
    if ckpt_manager.latest_checkpoint:
        ckpt.restore(ckpt_manager.latest_checkpoint).expect_partial()
        print("✅ Restored from checkpoint:", ckpt_manager.latest_checkpoint)
    else:
        print("Initializing from scratch (no saved generators, no checkpoint).")

    df_metrics = train()
    # Save ONLY because they did not exist
    # save_generators(G_photo2monet, F_monet2photo)
# Out:
# Initializing from scratch (no saved generators, no checkpoint).
# Epoch 1/3 | Step 1/25 | Dx=0.7794 Dy=0.8412 | G_adv=1.1756 F_adv=0.7062 | cycX=0.6421 cycY=0.6328 | G_total=14.6309
# Epoch 1/3 | Step 10/25 | Dx=0.7369 Dy=0.7474 | G_adv=0.8972 F_adv=0.7634 | cycX=0.4564 cycY=0.4799 | G_total=11.0232
# Epoch 1/3 | Step 20/25 | Dx=0.7151 Dy=0.7118 | G_adv=0.8322 F_adv=0.7546 | cycX=0.3720 cycY=0.3811 | G_total=9.1181
#
# ✅ Epoch 1 done in 10.21 min | saved: /kaggle/working/checkpoints_cyclegan/ckpt-1
# Final epoch metrics: Dx=0.7047, Dy=0.6984, G_adv=0.8229, F_adv=0.7528, cycX=0.3456, cycY=0.3533, G_total=8.5643
#
# Epoch 2/3 | Step 1/25 | Dx=0.6573 Dy=0.6533 | G_adv=0.7674 F_adv=0.7769 | cycX=0.2320 cycY=0.2366 | G_total=6.2301
# Epoch 2/3 | Step 10/25 | Dx=0.6691 Dy=0.6549 | G_adv=0.7524 F_adv=0.7524 | cycX=0.2231 cycY=0.2190 | G_total=5.9258
# Epoch 2/3 | Step 20/25 | Dx=0.6713 Dy=0.6574 | G_adv=0.7521 F_adv=0.7436 | cycX=0.2210 cycY=0.2133 | G_total=5.8388
#
# ✅ Epoch 2 done in 9.66 min | saved: /kaggle/working/checkpoints_cyclegan/ckpt-2
# Final epoch metrics: Dx=0.6701, Dy=0.6583, G_adv=0.7495, F_adv=0.7465, cycX=0.2164, cycY=0.2105, G_total=5.7652
#
# Epoch 3/3 | Step 1/25 | Dx=0.6923 Dy=0.6757 | G_adv=0.7544 F_adv=0.7414 | cycX=0.2029 cycY=0.1981 | G_total=5.5054
# Epoch 3/3 | Step 10/25 | Dx=0.6711 Dy=0.6739 | G_adv=0.7459 F_adv=0.7464 | cycX=0.2048 cycY=0.1873 | G_total=5.4137
# Epoch 3/3 | Step 20/25 | Dx=0.6660 Dy=0.6693 | G_adv=0.7460 F_adv=0.7512 | cycX=0.1949 cycY=0.1880 | G_total=5.3263
#
# ✅ Epoch 3 done in 9.65 min | saved: /kaggle/working/checkpoints_cyclegan/ckpt-3
# Final epoch metrics: Dx=0.6650, Dy=0.6694, G_adv=0.7490, F_adv=0.7552, cycX=0.1934, cycY=0.1881, G_total=5.3192
#    epoch    time_sec        Dx        Dy     G_adv     F_adv      cycX  \
# 0      1  612.697854  0.704671  0.698390  0.822927  0.752819  0.345580
# 1      2  579.685751  0.670120  0.658276  0.749540  0.746464  0.216431
# 2      3  578.712620  0.664984  0.669435  0.748998  0.755219  0.193446
#
#        cycY   G_total
# 0  0.353270  8.564253
# 1  0.210493  5.765245
# 2  0.188051  5.319192
# ✅ Saved metrics CSV to: /kaggle/working/cyclegan_training_metrics.csv

# %%
# =========================
# Visualization: Photo -> Monet (G) -> Photo (F)
# Row 1: original photos (X)
# Row 2: G_photo2monet(X)
# Row 3: F_monet2photo(G_photo2monet(X))  (cycle back)
# =========================

import matplotlib.pyplot as plt
import tensorflow as tf

def denorm_m11_to_01(img):
    # img in [-1, 1] -> [0, 1]
    return tf.clip_by_value((img + 1.0) / 2.0, 0.0, 1.0)

# Take one batch from photo_ds
real_x = next(iter(photo_ds))  # shape: (B, 256, 256, 3), in [-1, 1]
real_x_4 = real_x[:4]

# Forward + cycle 
fake_y_4 = G_photo2monet(real_x_4, training=False)          # X -> Y
cycled_x_4 = F_monet2photo(fake_y_4, training=False)        # X -> Y -> X

# Convert to displayable [0,1]
row1 = denorm_m11_to_01(real_x_4)
row2 = denorm_m11_to_01(fake_y_4)
row3 = denorm_m11_to_01(cycled_x_4)

# Plot 3x4
plt.figure(figsize=(16, 10))

for i in range(4):
    # Row 1: originals
    ax = plt.subplot(3, 4, i + 1)
    ax.imshow(row1[i].numpy())
    ax.set_title("Original (Photo)")
    ax.axis("off")

    # Row 2: G output
    ax = plt.subplot(3, 4, 4 + i + 1)
    ax.imshow(row2[i].numpy())
    ax.set_title("G: Photo → Monet")
    ax.axis("off")

    # Row 3: F output on G output (cycled back)
    ax = plt.subplot(3, 4, 8 + i + 1)
    ax.imshow(row3[i].numpy())
    ax.set_title("F: Monet → Photo (Cycle)")
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
# =========================
# Generate final Monet-style images with trained generator (CPU-only)
# Produces N images as JPG (256x256) from PHOTO domain using G_photo2monet
# =========================

OUT_DIR = Path("./generated_monet_jpg")
OUT_DIR.mkdir(parents=True, exist_ok=True)

N_GEN = 7000

# Ensure we use the trained generator in inference mode
G_photo2monet.trainable = False

def m11_to_uint8(img_m11):
    """
    img_m11: float tensor in [-1,1], shape (H,W,3)
    returns uint8 array in [0,255]
    """
    img01 = tf.clip_by_value((img_m11 + 1.0) / 2.0, 0.0, 1.0)
    img255 = tf.cast(tf.round(img01 * 255.0), tf.uint8)
    return img255.numpy()

# Iterate over photos and generate
photo_iter = iter(photo_ds)

count = 0
while count < N_GEN:
    batch = next(photo_iter)  # (B,256,256,3) in [-1,1]
    fake_y = G_photo2monet(batch, training=False)  # (B,256,256,3) in [-1,1]
    if count % 10  == 0:
        print("count: ", count)

    b = fake_y.shape[0]
    for i in range(b):
        if count >= N_GEN:
            break
        img = m11_to_uint8(fake_y[i])
        Image.fromarray(img).save(OUT_DIR / f"monet_{count:05d}.jpg", quality=95)
        count += 1

print(f"Saved {count} generated images to: {OUT_DIR.resolve()}")
# Out:
# count:  0
# count:  80
# count:  160
# count:  240
# count:  320
# count:  400
# count:  480
# count:  560
# count:  640
# count:  720
# count:  800
# count:  880
# count:  960
# count:  1040
# count:  1120
# count:  1200
# count:  1280
# count:  1360
# count:  1440
# count:  1520
# count:  1600
# count:  1680
# count:  1760
# count:  1840
# count:  1920
# count:  2000
# count:  2080
# count:  2160
# count:  2240
# count:  2320
# count:  2400
# count:  2480
# count:  2560
# count:  2640
# count:  2720
# count:  2800
# count:  2880
# count:  2960
# count:  3040
# count:  3120
# count:  3200
# count:  3280
# count:  3360
# count:  3440
# count:  3520
# count:  3600
# count:  3680
# count:  3760
# count:  3840
# count:  3920
# count:  4000
# count:  4080
# count:  4160
# count:  4240
# count:  4320
# count:  4400
# count:  4480
# count:  4560
# count:  4640
# count:  4720
# count:  4800
# count:  4880
# count:  4960
# count:  5040
# count:  5120
# count:  5200
# count:  5280
# count:  5360
# count:  5440
# count:  5520
# count:  5600
# count:  5680
# count:  5760
# count:  5840
# count:  5920
# count:  6000
# count:  6080
# count:  6160
# count:  6240
# count:  6320
# count:  6400
# count:  6480
# count:  6560
# count:  6640
# count:  6720
# count:  6800
# count:  6880
# count:  6960
# Saved 7000 generated images to: /kaggle/working/generated_monet_jpg

# %%
import zipfile
from pathlib import Path

zip_path = "images.zip"
img_dir = Path("./generated_monet_jpg")

with zipfile.ZipFile(zip_path, "w", zipfile.ZIP_DEFLATED) as zipf:
    for img_path in img_dir.glob("*.jpg"):
        zipf.write(img_path, arcname=img_path.name)

print(f"Created submission file: {zip_path}")
# Out:
# Created submission file: images.zip

# %% [markdown]
# ## Results
#
# The results of the CycleGAN training are evaluated qualitatively through visual inspection of the generated images.
#
# The Photo → Monet → Photo visualizations show that the generator is able to modify color distributions and textures in a way that resembles Monet-style paintings, while the cycle-consistency constraint helps preserve the overall structure of the original photographs.
#
# Across multiple samples, the generated images exhibit softer edges and more painterly color blending compared to the input photographs. However, the level of stylistic richness varies, and some outputs remain visually close to the original photos.
#
# Although the training losses appear numerically stable, visual quality is not uniform across all generated samples. This confirms that loss values alone are not sufficient to evaluate GAN performance and that qualitative inspection is essential when working with generative models.
#
# Finally, the trained generator was used to produce a full set of Monet-style images (256×256 JPG) for Kaggle submission, demonstrating a complete end-to-end workflow from model training to image generation.

# %% [markdown]
# ## Discussion
#
# This project demonstrates the application of Generative Adversarial Networks to artistic style generation using an unpaired image dataset.
# CycleGAN was selected because it enables image-to-image translation without paired examples, which aligns with the structure of the dataset.
#
# The main limitations of this work include a small number of training epochs, reduced model capacity, and CPU-only training. These constraints were chosen intentionally to keep the project lightweight and focused on conceptual understanding rather than leaderboard optimization.

# %% [markdown]
# ## Conclusion
#
# This mini-project implemented and trained a CycleGAN model to translate photographs into Monet-style images using an unpaired dataset. The main result is a working end-to-end pipeline that (1) trains a GAN-based translation model and (2) generates a full set of Monet-style images suitable for Kaggle submission.
#
# ### Key results (reiteration)
# Qualitative visualizations (Photo → Monet → Photo) show that the generator is able to introduce Monet-like color blending and painterly textures in multiple samples, while cycle-consistency helps preserve the coarse structure of the original photographs.
#
# ### What I learned
# This project provided practical experience with:
# - adversarial training dynamics (generator vs. discriminator),
# - the importance of cycle-consistency for unpaired translation,
# - the need to evaluate GAN outputs visually (not only via loss curves),
# - and the trade-off between model capacity, training stability, and computational cost.
#
# ### Why the model did not fully match Monet quality
# The main reasons the results are not comparable to real Monet paintings are:
# - **limited training time (few epochs / steps)**, which restricts convergence,
# - **reduced model capacity (filters/residual blocks)** chosen to keep training feasible,
# - and **CPU-only training**, which limits the amount of experimentation and the ability to run longer stable trainings.
#
# In practice, some configurations can produce losses that look stable while the generated images remain visually weak; therefore, visual inspection is essential for judging progress in GAN training.
#
# ### How to improve (future work)
# If more compute and time were available, improvements would include:
# - training for more epochs and steps with proper checkpointing,
# - increasing generator/discriminator capacity (more filters and residual blocks),
# - adding **identity loss** to better preserve color composition in some translations,
# - experimenting with alternative adversarial losses (e.g., least-squares GAN) for stability,
# - and using quantitative metrics (e.g., FID) alongside qualitative inspection to track progress more objectively.
#
# Overall, despite lightweight constraints, the project demonstrates that CycleGAN can learn meaningful stylistic features from Monet paintings and apply them to photographs in an unsupervised setting.
